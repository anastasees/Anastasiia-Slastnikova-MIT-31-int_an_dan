# %% [markdown]
# #Лабораторна робота 1
# **Тема:** Підготовка робочого середовища та робота з Jupyter Notebook
# **Мета:** Налаштувати середовище, вивчити основні можливості Jupyter Notebook

# %%
name = input("What is your name? ")
print(f"Hello, {name}!")
# Out:
# Hello, Anastasiia!

# %%
import numpy as np

# Створення масиву з 10 випадкових чисел
array = np.random.rand(10)
print("Масив з 10 випадкових чисел:")
print(array)

# Обчислення середнього значення
mean_value = np.mean(array)
print("Середнє значення масиву:")
print(mean_value)
# Out:
# Масив з 10 випадкових чисел:
# [0.21813697 0.54385228 0.90975009 0.13223921 0.69559255 0.20455646
#  0.73008879 0.26411593 0.27125908 0.20867786]
# Середнє значення масиву:
# 0.417826921323316
